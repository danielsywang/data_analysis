# %% [markdown]
# ## 项目背景与数据挖掘的目标
#
# 客户关系管理是各个航空公司的核心问题。客户关系管理的关键是通过客户分类来发掘客户价值，针对不同价值的客户采取不同的营销策略，实现企业利润最大化。
#
# 国内某航空公司面临旅客流失、竞争力下降和航空资源未充分利用等问题。通过建立合理的客户价值评估模型，对客户进行分类，分析比较不同客户群的价值，并制定相应的营销策略。
#
# 利用该航空公司的会员档案信息和乘坐航班记录实现以下目标：
#   * 对客户进行分类
#   * 对不同的客户类别进行特征分析，比较不同类客户的价值
#   * 对不同价值的客户类别提供个性化服务，制定相应的营销策略

# %% [markdown]
# 客户信息属性说明
#
# <figure><table>
# <thead>
# <tr><th style='text-align:left;' >属性中文</th><th style='text-align:left;' >属性英文</th><th style='text-align:left;' >备注</th></tr></thead>
# <tbody><tr><td style='text-align:left;' >会员卡号</td><td style='text-align:left;' >MEMBER_NO</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >入会时间</td><td style='text-align:left;' >FFP_DATE</td><td style='text-align:left;' >办理会员卡的开始的时间</td></tr><tr><td style='text-align:left;' >第一次飞行日期</td><td style='text-align:left;' >FIRST_FLIGHT_DATE</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >性别</td><td style='text-align:left;' >GENDER</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >会员卡级别</td><td style='text-align:left;' >FFP_TIER</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >工作地城市</td><td style='text-align:left;' >WORK_CITY</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >工作地所在省份</td><td style='text-align:left;' >WORK_PROVINCE</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >工作地所在国家</td><td style='text-align:left;' >WORK_COUNTRY</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >年龄</td><td style='text-align:left;' >age</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口的结束时间</td><td style='text-align:left;' >LOAD_TIME</td><td style='text-align:left;' >选取样本的时间宽度，距离现在最近的时间。</td></tr><tr><td style='text-align:left;' >飞行次数</td><td style='text-align:left;' >FLIGHT_COUNT</td><td style='text-align:left;' >频数</td></tr><tr><td style='text-align:left;' >观测窗口总基本积分</td><td style='text-align:left;' >BP_SUM</td><td style='text-align:left;' >航空公里的里程就相当于积分，积累一定分数可以兑换奖品和免费里程。</td></tr><tr><td style='text-align:left;' >第一年精英资格积分</td><td style='text-align:left;' >EP_SUM_YR_1</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第二年精英资格积分</td><td style='text-align:left;' >EP_SUM_YR_2</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第一年总票价</td><td style='text-align:left;' >SUM_YR_1</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第二年总票价</td><td style='text-align:left;' >SUM_YR_2</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口总飞行公里数</td><td style='text-align:left;' >SEG_KM_SUM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口总加权飞行公里数（Σ舱位折扣×航段距离）</td><td style='text-align:left;' >WEIGHTED_SEG_KM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >末次飞行日期</td><td style='text-align:left;' >LAST_FLIGHT_DATE</td><td style='text-align:left;' >最后一次飞行时间</td></tr><tr><td style='text-align:left;' >观测窗口季度平均飞行次数</td><td style='text-align:left;' >AVG_FLIGHT_COUNT</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口季度平均基本积分累积</td><td style='text-align:left;' >AVG_BP_SUM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观察窗口内第一次乘机时间至MAX（观察窗口始端，入会时间）时长</td><td style='text-align:left;' >BEGIN_TO_FIRST</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >最后一次乘机时间至观察窗口末端时长</td><td style='text-align:left;' >LAST_TO_END</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >平均乘机时间间隔</td><td style='text-align:left;' >AVG_INTERVAL</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观察窗口内最大乘机间隔</td><td style='text-align:left;' >MAX_INTERVAL</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口中第1年其他积分（合作伙伴、促销、外航转入等）</td><td style='text-align:left;' >ADD_POINTS_SUM_YR_1</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口中第2年其他积分（合作伙伴、促销、外航转入等）</td><td style='text-align:left;' >ADD_POINTS_SUM_YR_2</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >积分兑换次数</td><td style='text-align:left;' >EXCHANGE_COUNT</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >平均折扣率</td><td style='text-align:left;' >avg_discount</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第1年乘机次数</td><td style='text-align:left;' >P1Y_Flight_Count</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第2年乘机次数</td><td style='text-align:left;' >L1Y_Flight_Count</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第1年里程积分</td><td style='text-align:left;' >P1Y_BP_SUM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第2年里程积分</td><td style='text-align:left;' >L1Y_BP_SUM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口总精英积分</td><td style='text-align:left;' >EP_SUM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >观测窗口中其他积分（合作伙伴、促销、外航转入等）</td><td style='text-align:left;' >ADD_Point_SUM</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >非乘机积分总和</td><td style='text-align:left;' >Eli_Add_Point_Sum</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第2年非乘机积分总和</td><td style='text-align:left;' >L1Y_ELi_Add_Points</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >总累计积分</td><td style='text-align:left;' >Points_Sum</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第2年观测窗口总累计积分</td><td style='text-align:left;' >L1Y_Points_Sum</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第2年的乘机次数比率</td><td style='text-align:left;' >Ration_L1Y_Flight_Count</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第1年的乘机次数比率</td><td style='text-align:left;' >Ration_P1Y_Flight_Count</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第1年里程积分占最近两年积分比例</td><td style='text-align:left;' >Ration_P1Y_BPS</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >第2年里程积分占最近两年积分比例</td><td style='text-align:left;' >Ration_L1Y_BPS</td><td style='text-align:left;' >　</td></tr><tr><td style='text-align:left;' >非乘机的积分变动次数</td><td style='text-align:left;' >Point_NotFlight</td><td style='text-align:left;' >　</td></tr></tbody>
# </table></figure>

# %% [markdown]
# ## I. Import Data & Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

# More Data Preprocessing & Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer, OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# Data Viz
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1.数据整理（探索）

# %%
#-*- coding: utf-8 -*- 
#对数据进行基本的探索
#返回缺失值个数以及最大最小值

datafile= '../data/air_data.csv' #航空原始数据,第一行为属性标签
resultfile = '../tmp/explore.xls' #数据探索结果表

data = pd.read_csv(datafile, encoding = 'utf-8') #读取原始数据，指定UTF-8编码（需要用文本编辑器将数据装换为UTF-8编码）

# %%
data.columns
# Out:
# Index(['MEMBER_NO', 'FFP_DATE', 'FIRST_FLIGHT_DATE', 'GENDER', 'FFP_TIER',
#        'WORK_CITY', 'WORK_PROVINCE', 'WORK_COUNTRY', 'AGE', 'LOAD_TIME',
#        'FLIGHT_COUNT', 'BP_SUM', 'EP_SUM_YR_1', 'EP_SUM_YR_2', 'SUM_YR_1',
#        'SUM_YR_2', 'SEG_KM_SUM', 'WEIGHTED_SEG_KM', 'LAST_FLIGHT_DATE',
#        'AVG_FLIGHT_COUNT', 'AVG_BP_SUM', 'BEGIN_TO_FIRST', 'LAST_TO_END',
#        'AVG_INTERVAL', 'MAX_INTERVAL', 'ADD_POINTS_SUM_YR_1',
#        'ADD_POINTS_SUM_YR_2', 'EXCHANGE_COUNT', 'avg_discount',
#        'P1Y_Flight_Count', 'L1Y_Flight_Count', 'P1Y_BP_SUM', 'L1Y_BP_SUM',
#        'EP_SUM', 'ADD_Point_SUM', 'Eli_Add_Point_Sum', 'L1Y_ELi_Add_Points',
#        'Points_Sum', 'L1Y_Points_Sum', 'Ration_L1Y_Flight_Count',
#        'Ration_P1Y_Flight_Count', 'Ration_P1Y_BPS', 'Ration_L1Y_BPS',
#        'Point_NotFlight'],
#       dtype='object')

# %%
data.dtypes
# Out:
# MEMBER_NO                    int64
# FFP_DATE                    object
# FIRST_FLIGHT_DATE           object
# GENDER                      object
# FFP_TIER                     int64
# WORK_CITY                   object
# WORK_PROVINCE               object
# WORK_COUNTRY                object
# AGE                        float64
# LOAD_TIME                   object
# FLIGHT_COUNT                 int64
# BP_SUM                       int64
# EP_SUM_YR_1                  int64
# EP_SUM_YR_2                  int64
# SUM_YR_1                   float64
# SUM_YR_2                   float64
# SEG_KM_SUM                   int64
# WEIGHTED_SEG_KM            float64
# LAST_FLIGHT_DATE            object
# AVG_FLIGHT_COUNT           float64
# AVG_BP_SUM                 float64
# BEGIN_TO_FIRST               int64
# LAST_TO_END                  int64
# AVG_INTERVAL               float64
# MAX_INTERVAL                 int64
# ADD_POINTS_SUM_YR_1          int64
# ADD_POINTS_SUM_YR_2          int64
# ...

# %%
data
# Out:
#        MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0          54993  2006/11/02        2008/12/24      男         6            .
# 1          28065  2007/02/19        2007/08/03      男         6          NaN
# 2          55106  2007/02/01        2007/08/30      男         6            .
# 3          21189  2008/08/22        2008/08/23      男         5  Los Angeles
# 4          39546  2009/04/10        2009/04/15      男         6           贵阳
# ...          ...         ...               ...    ...       ...          ...
# 62983      18375  2011/05/20        2013/06/05      女         4           广州
# 62984      36041  2010/03/08        2013/09/14      男         4           佛山
# 62985      45690  2006/03/30        2006/12/02      女         4           广州
# 62986      61027  2013/02/06        2013/02/14      女         4           广州
# 62987      61340  2013/02/17        2013/02/17      女         4           上海
#
# ...

# %% [markdown]
# ## 空缺值分析

# %%
data[data.isnull().values==True]
# Out:
#        MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER WORK_CITY  \
# 1          28065  2007/02/19        2007/08/03      男         6       NaN
# 8          32197  2011/06/07        2011/07/01      男         5    DRANCY
# 17         58899  2010/11/10        2011/02/23      女         6     PARIS
# 21         41281  2011/06/07        2011/06/09      男         6    VECHEL
# 23         28474  2010/04/13        2010/04/13      男         6       NaN
# ...          ...         ...               ...    ...       ...       ...
# 62974      11163  2005/05/08        2005/08/26      男         4       NaN
# 62975      30765  2008/11/16        2013/11/30      男         4    TAIPEI
# 62977      16372  2012/12/20        2012/12/20      男         4        桃园
# 62979      34330  2013/03/16        2013/03/17      男         4      乌鲁木齐
# 62987      61340  2013/02/17        2013/02/17      女         4        上海
#
#       WORK_PROVINCE WORK_COUNTRY   AGE   LOAD_TIME  ...  ADD_Point_SUM  \
# ...

# %%
#将列中为空的个数统计出来
#3+2269+3248+26+420+551+138共计6655
data.isnull().sum()
# Out:
# MEMBER_NO                     0
# FFP_DATE                      0
# FIRST_FLIGHT_DATE             0
# GENDER                        3
# FFP_TIER                      0
# WORK_CITY                  2269
# WORK_PROVINCE              3248
# WORK_COUNTRY                 26
# AGE                         420
# LOAD_TIME                     0
# FLIGHT_COUNT                  0
# BP_SUM                        0
# EP_SUM_YR_1                   0
# EP_SUM_YR_2                   0
# SUM_YR_1                    551
# SUM_YR_2                    138
# SEG_KM_SUM                    0
# WEIGHTED_SEG_KM               0
# LAST_FLIGHT_DATE              0
# AVG_FLIGHT_COUNT              0
# AVG_BP_SUM                    0
# BEGIN_TO_FIRST                0
# LAST_TO_END                   0
# AVG_INTERVAL                  0
# MAX_INTERVAL                  0
# ADD_POINTS_SUM_YR_1           0
# ADD_POINTS_SUM_YR_2           0
# EXCHANGE_COUNT                0
# avg_discount                  0
# ...

# %%
data[data.isnull().any(axis=1)]
# Out:
#        MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER WORK_CITY  \
# 1          28065  2007/02/19        2007/08/03      男         6       NaN
# 8          32197  2011/06/07        2011/07/01      男         5    DRANCY
# 17         58899  2010/11/10        2011/02/23      女         6     PARIS
# 21         41281  2011/06/07        2011/06/09      男         6    VECHEL
# 23         28474  2010/04/13        2010/04/13      男         6       NaN
# ...          ...         ...               ...    ...       ...       ...
# 62974      11163  2005/05/08        2005/08/26      男         4       NaN
# 62975      30765  2008/11/16        2013/11/30      男         4    TAIPEI
# 62977      16372  2012/12/20        2012/12/20      男         4        桃园
# 62979      34330  2013/03/16        2013/03/17      男         4      乌鲁木齐
# 62987      61340  2013/02/17        2013/02/17      女         4        上海
#
#       WORK_PROVINCE WORK_COUNTRY   AGE   LOAD_TIME  ...  ADD_Point_SUM  \
# ...

# %%
## 含有空值的行数
data.isnull().any(axis=1).sum()
# Out:
# 4733

# %% [markdown]
# ## 本数据集共有62988个样本，含有空值的样本为4733个，比重较小，可以考虑删除。

# %% [markdown]
# ## 重复值分析：没有重复数据

# %%
data.duplicated().value_counts()
# Out:
# False    62988
# dtype: int64

# %%
unique_counts = pd.DataFrame.from_records([(col, data[col].nunique()) for col in data.columns],
                          columns=['Column_Name', 'Num_Unique']).sort_values(by=['Num_Unique'])
unique_counts
# Out:
#                 Column_Name  Num_Unique
# 9                 LOAD_TIME           1
# 12              EP_SUM_YR_1           1
# 3                    GENDER           2
# 4                  FFP_TIER           3
# 27           EXCHANGE_COUNT          28
# 29         P1Y_Flight_Count          82
# 8                       AGE          84
# 30         L1Y_Flight_Count          91
# 43          Point_NotFlight          99
# 7              WORK_COUNTRY         118
# 10             FLIGHT_COUNT         153
# 19         AVG_FLIGHT_COUNT         300
# 24             MAX_INTERVAL         706
# 21           BEGIN_TO_FIRST         730
# 18         LAST_FLIGHT_DATE         731
# 22              LAST_TO_END         731
# 6             WORK_PROVINCE        1185
# 40  Ration_P1Y_Flight_Count        1215
# 39  Ration_L1Y_Flight_Count        1215
# 1                  FFP_DATE        3068
# 33                   EP_SUM        3101
# 13              EP_SUM_YR_2        3101
# ...

# %% [markdown]
# ## 本数据集共有62988个样本，会员卡号（MEMBER_NO）:62988，说明数据不重复
# ## 观测窗口的结束时间(LOAD_TIME)、第一年精英资格积分（EP_SUM_YR_1）为1个值，如果生成新数据要用到，产生新数据后删除。

# %% [markdown]
# ### B. 分离数据类型
# Pandas所支持的数据类型:
# 1. float
# 2. int
# 3. bool
# 4. datetime64[ns]
# 5. datetime64[ns, tz]
# 6. timedelta[ns]
# 7. category
# 8. object
#
# 默认的数据类型是int64,float64.
#
# 通常，我们会遇到 5-6 种类型的数据。
#
# 1. Numerical数字 *(1.3, -2.345, 6,423.1)*
# 2. Categorical分类
#     - Binary二值 *(True/False, 0/1, Heads/Tails)*
#     - Ordinal序数 *(Low, Medium, High)*
#     - Nominal标称 *(Red, Blue, Purple)*
# 3. Date/Time日期/时间
# 4. Text文本
# 5. Image图像
# 6. Sound声音
#
# 本项目我们没有任何文本、图像或声音数据，因此我们将处理数字、分类和日期/时间。

# %% [markdown]
# ## 日期/时间类型特征分析

# %%
dt_cols=['FFP_DATE','FIRST_FLIGHT_DATE','LOAD_TIME','LAST_FLIGHT_DATE']

# %%
for col in dt_cols:
    data[col]=pd.to_datetime(data[col],infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ...

# %% [markdown]
# 日期从object转成datetime出错
# ~\Anaconda3\lib\site-packages\six.py in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 2014/2/29  0:00:00
# 从dtypes可以看出是LAST_FLIGHT_DATE没有转换成功！

# %%
data.dtypes
# Out:
# MEMBER_NO                           int64
# FFP_DATE                   datetime64[ns]
# FIRST_FLIGHT_DATE          datetime64[ns]
# GENDER                             object
# FFP_TIER                            int64
# WORK_CITY                          object
# WORK_PROVINCE                      object
# WORK_COUNTRY                       object
# AGE                               float64
# LOAD_TIME                  datetime64[ns]
# FLIGHT_COUNT                        int64
# BP_SUM                              int64
# EP_SUM_YR_1                         int64
# EP_SUM_YR_2                         int64
# SUM_YR_1                          float64
# SUM_YR_2                          float64
# SEG_KM_SUM                          int64
# WEIGHTED_SEG_KM                   float64
# LAST_FLIGHT_DATE                   object
# AVG_FLIGHT_COUNT                  float64
# AVG_BP_SUM                        float64
# BEGIN_TO_FIRST                      int64
# ...

# %% [markdown]
# 将LAST_FLIGHT_DATE中'2014/2/29'改为'2014/2/28/'

# %%
data[dt_cols[3]]=np.where(data[dt_cols[3]].str.contains('2014/2/29'),'2014/2/28/',data[dt_cols[3]])
data[dt_cols[3]]=pd.to_datetime(data[dt_cols[3]],infer_datetime_format=True)

# %%
data.T
# Out:
#                                        0                    1      \
# MEMBER_NO                              54993                28065
# FFP_DATE                 2006-11-02 00:00:00  2007-02-19 00:00:00
# FIRST_FLIGHT_DATE        2008-12-24 00:00:00  2007-08-03 00:00:00
# GENDER                                     男                    男
# FFP_TIER                                   6                    6
# WORK_CITY                                  .                  NaN
# WORK_PROVINCE                             北京                   北京
# WORK_COUNTRY                              CN                   CN
# AGE                                       31                   42
# LOAD_TIME                2014-03-31 00:00:00  2014-03-31 00:00:00
# FLIGHT_COUNT                             210                  140
# BP_SUM                                505308               362480
# EP_SUM_YR_1                                0                    0
# ...

# %% [markdown]
# ## 增加一个新特征 FIRST_LAST_DAYS:第一次飞行到末次飞行时间（天）

# %%
data['FIRST_LAST_DAYS']=data['LAST_FLIGHT_DATE']-data['FIRST_FLIGHT_DATE']

# %% [markdown]
# ## 由于有BEGIN_TO_FIRST(最后一次乘机时间至观察窗口末端时长)、LAST_TO_END（平均乘机时间间隔），又增加了FIRST_LAST_DAYS（第一次飞行到末次飞行时间）,dt_cols中的数据不需要了，在数据清洗时删除。
# dt_cols=['FFP_DATE','FIRST_FLIGHT_DATE','LOAD_TIME','LAST_FLIGHT_DATE']

# %% [markdown]
# ## Object类型特征分析

# %%
cat_df=data.select_dtypes('object')
cat_df
# Out:
#       GENDER    WORK_CITY WORK_PROVINCE WORK_COUNTRY
# 0          男            .            北京           CN
# 1          男          NaN            北京           CN
# 2          男            .            北京           CN
# 3          男  Los Angeles            CA           US
# 4          男           贵阳            贵州           CN
# ...      ...          ...           ...          ...
# 62983      女           广州            广东           CN
# 62984      男           佛山            广东           CN
# 62985      女           广州            广东           CN
# 62986      女           广州            广东           CN
# 62987      女           上海             .           CN
#
# [62988 rows x 4 columns]

# %%
print(cat_df.value_counts(sort=False))
# Out:
# GENDER  WORK_CITY  WORK_PROVINCE  WORK_COUNTRY
# 女       *          北京             CN               1
#         -          -              CN              18
#                                   HK               1
#                    --             CN               1
#                    GYEONGGI       KR               1
#                                                   ..
# 男       龙海         福建             CN               7
#         龙游         浙江             CN               1
#         －          －              JP               1
#         ．          北京             CN               2
#         ＴＷ         ＴＷ             TW               1
# Length: 4739, dtype: int64

# %%
cat_df[cat_df.columns[3]].value_counts()
# Out:
# CN    57748
# HK      991
# JP      875
# KR      790
# US      575
#       ...
# IA        1
# RE        1
# PR        1
# CD        1
# MS        1
# Name: WORK_COUNTRY, Length: 118, dtype: int64

# %%
#可以计算空值的个数，也可以查看是否有空值
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62988 entries, 0 to 62987
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GENDER         62985 non-null  object
#  1   WORK_CITY      60719 non-null  object
#  2   WORK_PROVINCE  59740 non-null  object
#  3   WORK_COUNTRY   62962 non-null  object
# dtypes: object(4)
# memory usage: 1.9+ MB

# %%
#只显示存在缺失值的行列，清楚的确定缺失值的位置。
cat_df[cat_df.isnull().values==True]
# Out:
#          FFP_DATE FIRST_FLIGHT_DATE GENDER WORK_CITY WORK_PROVINCE  \
# 1      2007/02/19        2007/08/03      男       NaN            北京
# 8      2011/06/07        2011/07/01      男    DRANCY           NaN
# 17     2010/11/10        2011/02/23      女     PARIS           NaN
# 23     2010/04/13        2010/04/13      男       NaN            CA
# 24     2010/02/14        2010/03/01      女       NaN           NaN
# ...           ...               ...    ...       ...           ...
# 62970  2005/03/11        2005/06/16      女       NaN           NaN
# 62974  2005/05/08        2005/08/26      男       NaN           NaN
# 62974  2005/05/08        2005/08/26      男       NaN           NaN
# 62975  2008/11/16        2013/11/30      男    TAIPEI           NaN
# 62977  2012/12/20        2012/12/20      男        桃园           NaN
#
#       WORK_COUNTRY   LOAD_TIME LAST_FLIGHT_DATE
# 1               CN  2014/03/31       2014/03/25
# 8               FR  2014/03/31       2014/03/26
# ...

# %%
#缺失观测的行数data3.isnull().any(axis = 1).sum()
#缺失观测的比例data3.isnull().any(axis = 1).sum()/data3.shape[0]
cat_df[cat_df.isnull().any(axis=1)]
# Out:
#       GENDER WORK_CITY WORK_PROVINCE WORK_COUNTRY
# 1          男       NaN            北京           CN
# 8          男    DRANCY           NaN           FR
# 17         女     PARIS           NaN           FR
# 23         男       NaN            CA           US
# 24         女       NaN           NaN           FR
# ...      ...       ...           ...          ...
# 62967      男       NaN            广东           CN
# 62970      女       NaN           NaN           CN
# 62974      男       NaN           NaN           CN
# 62975      男    TAIPEI           NaN           TW
# 62977      男        桃园           NaN           TW
#
# [3752 rows x 4 columns]

# %%
list(cat_df['GENDER'].sort_values(ascending=True).unique())
# Out:
# ['女', '男', nan]

# %%
list(cat_df['WORK_CITY'].sort_values(ascending=True).unique())
# Out:
# ['*',
#  '**',
#  '-',
#  '--',
#  '-晋江',
#  '-武汉',
#  '.',
#  '.上海',
#  '.北京',
#  '.昆明',
#  '.朝阳区',
#  '.浠水',
#  '.深圳',
#  '.重庆',
#  '/',
#  '0',
#  '1',
#  '1-2-1 OHTEMACHI,CHIYODA-KU,',
#  '12961',
#  '13720514406',
#  '33 CONDUIT ROAD',
#  '5',
#  '50668 KOELN',
#  '6400sonderboro',
#  '75003',
#  '9460 BNOUST',
#  '=',
#  '?',
#  'AACMEN',
#  'ABA',
#  'ABBOTSFORD',
#  'ABIKO-SHI',
#  'ACCRA',
#  'ACT',
#  'ACTONA MEADOWS',
#  'ADACHI-KU',
#  'AHMEDABAD',
#  'AICADIA',
#  'AIHAMBRA',
#  'AKAIWA CITY',
#  'AKISHIMA-SHI',
#  'ALHAMBRA',
#  'ALHAMBRA CA',
#  'ALISO VIEJO',
#  'ALLHAMING',
#  'ALMATY',
#  'ALMHULT',
#  'ALOR SETAR',
#  'ALOR STAR',
#  'ALPHARETTA',
#  'ALPINE',
#  'ALTA LOMA',
#  'ALTRINC HAM',
#  'AMA-GUN',
#  'AMAGASAKI',
#  'AMAGASAKI-SHI',
#  'AMAHEIM',
#  'AMNILA',
#  'AMSTELVEEN',
#  'AMSTERDAM',
#  'ANAHEIM',
#  'ANDE',
#  'ANDRESY',
#  'ANG MO LAO',
#  'ANGELES CITY',
#  'ANGYO-SHI',
#  'ANJO-SHI',
#  'ANNAPOLIS',
#  'ANPACHI-GUN',
#  'ANSAN SHI',
# ...

# %%
list(cat_df['WORK_PROVINCE'].sort_values(ascending=True).unique())
# Out:
# ['*',
#  '**',
#  '-',
#  '--',
#  '---',
#  '-hkg',
#  '-上海',
#  '-湖北',
#  '.',
#  '..',
#  '.上海',
#  '.云南',
#  '.北京',
#  '.广西壮族自治区',
#  '.湖北',
#  '.重庆市',
#  '/',
#  '0',
#  '0401 MM P.O.BOX 789',
#  '1',
#  '120330',
#  '1964-07-12',
#  '33',
#  '92300',
#  '94000',
#  '94省',
#  '96081184',
#  '=',
#  'AARGAU',
#  'ABIA',
#  'ACCRA',
#  'ACT',
#  'AICH',
#  'AICHI',
#  'AICHI PREF',
#  'AICHI-KEN',
#  'AICHIKEN',
#  'AKITA',
#  'ALHAMBRA CA',
#  'ALICANTE',
#  'AMSTELVEEN',
#  'AMSTERDAM',
#  'ANAMBHASTATE-ONITSHA',
#  'ANAMBRA',
#  'ANDE',
#  'ANSAN-SI',
#  'ANTWERP',
#  'AOMORI-KEN',
#  'ARIZDNA',
#  'ARROMD',
#  'AU',
#  'AUD',
#  'AUS',
#  'AUSTARLIA',
#  'AUSTRALA',
#  'AUSTRIA',
#  'AZ',
#  'Aichi',
#  'Aichi-ken',
#  'Amberg',
#  'Austria',
#  'B.C',
#  'B.C.',
#  'BAKU',
#  'BALI',
#  'BANGKOK',
#  'BANGPHLAT',
#  'BANGZADESH',
#  'BARI',
#  'BATAPGAS',
#  'BAVARIA',
#  'BC',
#  'BEDFORDSHIRE',
#  'BEIJING',
#  'BELGIUN',
#  'BERGAMO',
#  'BETHUNGRA',
#  'BIJING',
# ...

# %%
list(cat_df['WORK_COUNTRY'].sort_values(ascending=True).unique())
# Out:
# ['AA',
#  'AB',
#  'AE',
#  'AN',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AZ',
#  'BB',
#  'BD',
#  'BE',
#  'BG',
#  'BI',
#  'BN',
#  'BR',
#  'BS',
#  'BZ',
#  'CA',
#  'CC',
#  'CD',
#  'CH',
#  'CL',
#  'CM',
#  'CN',
#  'CR',
#  'CY',
#  'DE',
#  'DK',
#  'EC',
#  'EG',
#  'ES',
#  'FA',
#  'FI',
#  'FL',
#  'FO',
#  'FR',
#  'GB',
#  'GE',
#  'GH',
#  'GL',
#  'GN',
#  'GT',
#  'GU',
#  'HK',
#  'HN',
#  'HU',
#  'IA',
#  'ID',
#  'IE',
#  'IL',
#  'IN',
#  'IR',
#  'IT',
#  'JP',
#  'KA',
#  'KE',
#  'KH',
#  'KO',
#  'KR',
#  'KZ',
#  'LA',
#  'LB',
#  'MA',
#  'MN',
#  'MO',
#  'MS',
#  'MV',
#  'MX',
#  'MY',
#  'MZ',
#  'NE',
#  'NG',
#  'NI',
#  'NL',
#  'NO',
#  'NZ',
#  'OM',
#  'PA',
#  'PE',
#  'PH',
#  'PK',
#  'PN',
#  'PP',
#  'PR',
#  'PS',
#  'PT',
#  'RE',
#  'RO',
#  'RU',
#  'SA',
#  'SE',
#  'SG',
#  'SI',
#  'SK',
#  'SN',
#  'SU',
#  'SW',
#  'TH',
#  'TK',
#  'TR',
#  'TW',
#  'UA',
#  'UK',
#  'US',
#  'UV',
#  'UY',
#  'UZ',
#  'VN',
#  'VT',
#  'YE',
# ...

# %% [markdown]
# ## GENDER有3个空数据，这好处理,但是这个数据对我们分析没有什么帮助。WORK_CITY、WORK_PROVINCE、WORK_COUNTRY有大量的无效数据，数据质量太差，无法做出进一步的分析，在数据清洗时删除这些列。

# %% [markdown]
# ## 数字类型特征分析

# %%
num_df=data.select_dtypes(['int','float'])
num_df.T
# Out:
#                                  0              1              2      \
# AGE                          31.000000      42.000000      40.000000
# SUM_YR_1                 239560.000000  171483.000000  163618.000000
# SUM_YR_2                 234188.000000  167434.000000  164982.000000
# WEIGHTED_SEG_KM          558440.140000  367777.200000  355966.500000
# AVG_FLIGHT_COUNT             26.250000      17.500000      16.875000
# AVG_BP_SUM                63163.500000   45310.000000   43894.875000
# AVG_INTERVAL                  3.483254       5.194245       5.298507
# avg_discount                  0.961639       1.252314       1.254676
# Ration_L1Y_Flight_Count       0.509524       0.514286       0.518519
# Ration_P1Y_Flight_Count       0.490476       0.485714       0.481481
# Ration_P1Y_BPS                0.487221       0.489289       0.481467
# Ration_L1Y_BPS                0.512777       0.510708       0.518530
#
# ...

# %%
num_df.describe()
# Out:
#                 AGE       SUM_YR_1       SUM_YR_2  WEIGHTED_SEG_KM  \
# count  62568.000000   62437.000000   62850.000000     62988.000000
# mean      42.476346    5355.376064    5604.026014     12777.152439
# std        9.885915    8109.450147    8703.364247     17578.586695
# min        6.000000       0.000000       0.000000         0.000000
# 25%       35.000000    1003.000000     780.000000      3219.045000
# 50%       41.000000    2800.000000    2773.000000      6978.255000
# 75%       48.000000    6574.000000    6845.750000     15299.632500
# max      110.000000  239560.000000  234188.000000    558440.140000
#
#        AVG_FLIGHT_COUNT    AVG_BP_SUM  AVG_INTERVAL  avg_discount  \
# count      62988.000000  62988.000000  62988.000000  62988.000000
# mean           1.542154   1421.440249     67.749788      0.721558
# std            1.786996   2083.121324     77.517866      0.185427
# min            0.250000      0.000000      0.000000      0.000000
# ...

# %%
list(num_df[num_df.columns[11]].sort_values().unique())
# Out:
# [0.0,
#  0.008523333,
#  0.008910274,
#  0.009805364,
#  0.010413412,
#  0.012586532,
#  0.013572204,
#  0.014089478,
#  0.015034203,
#  0.015441631,
#  0.015892521,
#  0.01592864,
#  0.016263865,
#  0.017924406,
#  0.017984343,
#  0.018490618,
#  0.018826241,
#  0.019129459,
#  0.019248592,
#  0.019530294,
#  0.019662588,
#  0.019958963,
#  0.019960791,
#  0.020434282,
#  0.020896458,
#  0.021727563,
#  0.022244962,
#  0.02235886,
#  0.02241047,
#  0.02258662,
#  0.022675112,
#  0.022798982,
#  0.023995201,
#  0.024348673,
#  0.024394046,
#  0.024736148,
#  0.025373737,
#  0.02555668,
#  0.025807061,
#  0.025935442,
#  0.026143099,
#  0.026390714,
#  0.026486558,
#  0.026490066,
#  0.02685743,
#  0.026915275,
#  0.027207183,
#  0.027344818,
#  0.027777778,
#  0.02811245,
#  0.028435749,
#  0.028454712,
#  0.028624589,
#  0.028727377,
#  0.028760984,
#  0.028778583,
#  0.028785262,
#  0.029091898,
#  0.029109892,
#  0.029369548,
#  0.029453366,
#  0.029801797,
#  0.030133448,
# ...

# %% [markdown]
# ## 异常数据
# 以下数据出现0
#
# - 第一年总票价SUM_YR_1
# - 第二年总票价SUM_YR_2
# - 观测窗口总飞行公里数SEG_KM_SUM
# - 平均乘机时间间隔AVG_INTERVAL

# %%
num_df.duplicated().value_counts()
# Out:
# False    62966
# True        22
# dtype: int64

# %%
num_df.hist(figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'SUM_YR_1'}>,
#         <AxesSubplot:title={'center':'SUM_YR_2'}>],
#        [<AxesSubplot:title={'center':'WEIGHTED_SEG_KM'}>,
#         <AxesSubplot:title={'center':'AVG_FLIGHT_COUNT'}>,
#         <AxesSubplot:title={'center':'AVG_BP_SUM'}>],
#        [<AxesSubplot:title={'center':'AVG_INTERVAL'}>,
#         <AxesSubplot:title={'center':'avg_discount'}>,
#         <AxesSubplot:title={'center':'Ration_L1Y_Flight_Count'}>],
#        [<AxesSubplot:title={'center':'Ration_P1Y_Flight_Count'}>,
#         <AxesSubplot:title={'center':'Ration_P1Y_BPS'}>,
#         <AxesSubplot:title={'center':'Ration_L1Y_BPS'}>]], dtype=object)

# %%
num_df.isnull().any()
# Out:
# AGE                         True
# SUM_YR_1                    True
# SUM_YR_2                    True
# WEIGHTED_SEG_KM            False
# AVG_FLIGHT_COUNT           False
# AVG_BP_SUM                 False
# AVG_INTERVAL               False
# avg_discount               False
# Ration_L1Y_Flight_Count    False
# Ration_P1Y_Flight_Count    False
# Ration_P1Y_BPS             False
# Ration_L1Y_BPS             False
# dtype: bool

# %%
list(num_df.columns[num_df.isnull().any()])
# Out:
# ['AGE', 'SUM_YR_1', 'SUM_YR_2']

# %%
num_df[num_df['AGE'].isnull().values==True]
# Out:
#        AGE  SUM_YR_1  SUM_YR_2  WEIGHTED_SEG_KM  AVG_FLIGHT_COUNT  \
# 21     NaN   46800.0  198224.0        227815.38          2.875000
# 335    NaN   45211.0   21663.0        104790.76          1.500000
# 707    NaN   29640.0   38853.0         80236.84          4.250000
# 1282   NaN   16918.0    5400.0         63779.60          1.428571
# 1562   NaN   46808.0   48004.0         58487.26          8.125000
# ...    ...       ...       ...              ...               ...
# 62632  NaN       0.0    1109.0           638.40          0.250000
# 62654  NaN    2058.0       0.0           625.60          0.500000
# 62719  NaN     566.0       0.0           589.00          0.250000
# 62777  NaN       0.0    1300.0           552.00          0.250000
# 62801  NaN     560.0       0.0           528.00          0.250000
#
#          AVG_BP_SUM  AVG_INTERVAL  avg_discount  Ration_L1Y_Flight_Count  \
# 21     31946.625000     32.909091      1.061631                 0.652174
# ...

# %%
num_df[num_df['SUM_YR_1'].isnull().values==True]
# Out:
#         AGE  SUM_YR_1  SUM_YR_2  WEIGHTED_SEG_KM  AVG_FLIGHT_COUNT  \
# 5595   55.0       NaN       0.0         31997.60             2.875
# 6605   31.0       NaN       0.0         28884.90             4.750
# 10196  32.0       NaN       0.0         21659.00             1.875
# 16897  37.0       NaN       0.0         14373.05             2.500
# 18177  65.0       NaN       0.0         13473.00             1.000
# ...     ...       ...       ...              ...               ...
# 62923  40.0       NaN       0.0           373.00             0.400
# 62943  49.0       NaN       0.0           317.05             0.400
# 62955  35.0       NaN       0.0           291.20             0.250
# 62979  41.0       NaN       0.0           186.50             0.400
# 62987  29.0       NaN       0.0             0.00             0.400
#
#        AVG_BP_SUM  AVG_INTERVAL  avg_discount  Ration_L1Y_Flight_Count  \
# 5595     3746.625     14.227273      0.821863                      0.0
# ...

# %%
num_df[num_df['SUM_YR_2'].isnull().values==True]
# Out:
#         AGE  SUM_YR_1  SUM_YR_2  WEIGHTED_SEG_KM  AVG_FLIGHT_COUNT  \
# 29671  52.0       0.0       NaN          7602.02             0.750
# 30880  38.0       0.0       NaN          7181.50             1.375
# 31026  48.0       0.0       NaN          7134.12             1.250
# 34847  38.0       0.0       NaN          5953.02             0.250
# 35937  30.0       0.0       NaN          5652.95             0.500
# ...     ...       ...       ...              ...               ...
# 62824  28.0       0.0       NaN           502.26             0.250
# 62825  27.0       0.0       NaN           502.26             0.400
# 62842  67.0       0.0       NaN           484.88             0.250
# 62914  41.0       0.0       NaN           384.19             0.250
# 62915  52.0       0.0       NaN           384.19             0.250
#
#        AVG_BP_SUM  AVG_INTERVAL  avg_discount  Ration_L1Y_Flight_Count  \
# 29671     654.750      7.600000      0.748599                      1.0
# ...

# %%
num_new=num_df[np.abs(num_df-num_df.mean())>3*num_df.std()]
num_new.notnu()
# Out:
#        AGE  SUM_YR_1  SUM_YR_2  WEIGHTED_SEG_KM  AVG_FLIGHT_COUNT  AVG_BP_SUM  \
# 0      NaN  239560.0  234188.0        558440.14            26.250   63163.500
# 1      NaN  171483.0  167434.0        367777.20            17.500   45310.000
# 2      NaN  163618.0  164982.0        355966.50            16.875   43894.875
# 3      NaN  116350.0  125500.0        306900.88               NaN   42164.250
# 4      NaN  124560.0  130702.0        300834.06            19.000   34230.500
# ...    ...       ...       ...              ...               ...         ...
# 62983  NaN       NaN       NaN              NaN               NaN         NaN
# 62984  NaN       NaN       NaN              NaN               NaN         NaN
# 62985  NaN       NaN       NaN              NaN               NaN         NaN
# 62986  NaN       NaN       NaN              NaN               NaN         NaN
# 62987  NaN       NaN       NaN              NaN               NaN         NaN
#
# ...

# %%
num_df_cols=list(num_df.columns)
num_df_cols
# Out:
# ['AGE',
#  'SUM_YR_1',
#  'SUM_YR_2',
#  'WEIGHTED_SEG_KM',
#  'AVG_FLIGHT_COUNT',
#  'AVG_BP_SUM',
#  'AVG_INTERVAL',
#  'avg_discount',
#  'Ration_L1Y_Flight_Count',
#  'Ration_P1Y_Flight_Count',
#  'Ration_P1Y_BPS',
#  'Ration_L1Y_BPS']

# %%
for col in num_df_cols:
    num_df.boxplot(column=col,figsize=(15,10))

# %%
num_df.boxplot(column=num_df_cols[0],figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
num_df.boxplot(column=num_df_cols[11],figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
from scipy import stats

# %%
num_df[(np.abs(stats.zscore(num_df)) > 3).all(axis=1)]
# Out:
# C:\Users\SF\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [AGE, SUM_YR_1, SUM_YR_2, WEIGHTED_SEG_KM, AVG_FLIGHT_COUNT, AVG_BP_SUM, AVG_INTERVAL, avg_discount, Ration_L1Y_Flight_Count, Ration_P1Y_Flight_Count, Ration_P1Y_BPS, Ration_L1Y_BPS]
# Index: []

# %%
box_plot=num_df.boxplot(return_type='both')

# %% [markdown]
# ## E. 评估缺失值
# 此时不要填充或估算它们！我们想在训练/测试分割后填充缺失值。
#
# 在本节中，我们需要提出一个关于如何解决缺失值的策略。大多数机器学习算法（除了像XGBoost这样的算法）无法处理 NA 值，因此我们需要处理它们。
#
# 您有两个选择，我将在下面描述每个选项的一些策略：
#
# 1. **删除它们**
#     - 特定列中是否有很多缺失值？如果缺少太多，也许它不是很有用。
#     - 特定行中是否有很多缺失值？也许这种缺失是由合理的或数据收集失败引起的。调查这些，以防您可以在丢弃它们之前合理地确定它们丢失的原因。
#     - 有些行不包含您感兴趣的响应变量吗？也许您想预测priceAirbnb 列表。监督学习方法要求标签 ( price) 存在，因此我们可以忽略这些行。
# 2. **填补他们**（警告：这是一般不伟大实践，以填补缺失值之前，你训练/测试分割你的数据你。可以填补缺失值现在如果这是一个一次性的分析，但如果这是你想要的东西在实践中实现，你希望能够测试您的整个预处理工作流程以评估它的好坏。将您填充缺失值的策略视为您想要调整的另一个超参数。）
#     - 从其他列推断缺失值的值。（例如，如果state缺少，但是city是旧金山，state可能是CA）
#     - 用平均值、中位数或众数填充数值。
#     - 用最频繁的值填充分类值。
#     - 使用机器学习技术来预测缺失值。（查看IterativeImputer从sklearn这样做的方法。）

# %%
数据清洗分为三步（文末有大礼赠送）：
重复值处理——删除（有几个相同就删除还是全部得相同）
缺失值处理——删除，填充（均值，众数，中位数，前后相邻值），插值（拉格朗日插值，牛顿插值）
异常值处理——describe进行描述性分析+散点图+箱型图定位异常值，处理方法：删除，视为缺失值

# %% [markdown]
# 一、重复值处理
# ① 先用duplicated()方法进行逻辑判断，确定是否有重复值
# ② 再用duplicates（subset,keep,inplace)方法对某几列下面的重复行删除
# subset:以哪几列作为基准列，判断是否重复，如果不写则默认所有列都要重复才算
# keep: 保留哪一个，fist-保留首次出现的，last-保留最后出现的，False-重复的一个都不保留，默认为first
# inplace: 是否进行替换，最好选择False，保留原始数据，默认也是False
# data.drop_duplicates(subset=["订单号","订单行"],keep='first',inplace=True)
# print(data.duplicated().value_counts())

# %%
二、缺失值处理
1、缺失值查找：
先通过isnull函数看一下是否有空值，结果是有空值的地方显示为True，没有的显示为False；
再通过isnull().any()直接看每一列是否有空值，这个是只要这一列有1个空值，结果就是True;
如果想具体看哪几行有空值，可以再用data.isnull().values==True来定位
print(data.isnull())
print(data.isnull().any())
print(data[data.isnull().values==True])

2、缺失值处理
① 删除缺失值
dropna(axis,subset,how,thresh,inplace)
axis: 删除行还是列，行是0或index,列是1或column，默认是行
subst: 删除某几列的缺失值，可选，默认为所有列
how: any or all，any表明只要出现1个就删除，all表示所有列均为na才删
thresh: 缺失值的数量标准，达到这个阈值才会删除
inplace: 是否替换
data.dropna(how='any', axis=0,inplace=True)
print(data.isnull().any())

②缺失值填充
fillna(value,method,{},limit,inplace,axis)
value: 可以传入一个字符串或数字替代Na，值可以是指定的或者平均值，众数或中位数等
method: 有ffill（用前一个填充）和bfill（用后一个填充）两种
{}： 可以根据不同的列填充不同的值，列为键，填充值为值
limit: 限定填充的数量
inplace: 是否直接在原文件修改
axis: 填充的方向，默认是0，按行填充
print(data1.fillna(0))
print(data1.fillna("missing",limit=1))
print(data1.fillna({"订单号": "下次再补", "数量": "估计"}))
print(data1.fillna(method="ffill"))
data1.fillna(method="bfill",inplace=True)
print(data1.fillna(data1.median()))
③缺失值插值

# %%
data.head(5)
# Out:
#    MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0      54993  2006/11/02        2008/12/24      男         6            .
# 1      28065  2007/02/19        2007/08/03      男         6          NaN
# 2      55106  2007/02/01        2007/08/30      男         6            .
# 3      21189  2008/08/22        2008/08/23      男         5  Los Angeles
# 4      39546  2009/04/10        2009/04/15      男         6           贵阳
#
#   WORK_PROVINCE WORK_COUNTRY   AGE   LOAD_TIME  ...  ADD_Point_SUM  \
# 0            北京           CN  31.0  2014/03/31  ...          39992
# 1            北京           CN  42.0  2014/03/31  ...          12000
# 2            北京           CN  40.0  2014/03/31  ...          15491
# 3            CA           US  64.0  2014/03/31  ...              0
# 4            贵州           CN  48.0  2014/03/31  ...          22704
#
#    Eli_Add_Point_Sum  L1Y_ELi_Add_Points  Points_Sum  L1Y_Points_Sum  \
# ...

# %%
explore = data.describe(percentiles = [], include = 'all').T #包括对数据的基本描述，percentiles参数是指定计算多少的分位数表（如1/4分位数、中位数等）；T是转置，转置后更方便查阅
explore
# Out:
#                          count unique         top   freq      mean       std  \
# MEMBER_NO                62988    NaN         NaN    NaN   31494.5   18183.2
# FFP_DATE                 62988   3068  2011/01/13    184       NaN       NaN
# FIRST_FLIGHT_DATE        62988   3406  2013/02/16     96       NaN       NaN
# GENDER                   62985      2           男  48134       NaN       NaN
# FFP_TIER                 62988    NaN         NaN    NaN   4.10216  0.373856
# WORK_CITY                60719   3310          广州   9385       NaN       NaN
# WORK_PROVINCE            59740   1185          广东  17507       NaN       NaN
# WORK_COUNTRY             62962    118          CN  57748       NaN       NaN
# AGE                      62568    NaN         NaN    NaN   42.4763   9.88591
# LOAD_TIME                62988      1  2014/03/31  62988       NaN       NaN
# FLIGHT_COUNT             62988    NaN         NaN    NaN   11.8394   14.0495
# ...

# %%
explore['null'] = len(data)-explore['count'] #describe()函数自动计算非空值数，需要手动计算空值数
explore
# Out:
#                          count unique         top   freq      mean       std  \
# MEMBER_NO                62988    NaN         NaN    NaN   31494.5   18183.2
# FFP_DATE                 62988   3068  2011/01/13    184       NaN       NaN
# FIRST_FLIGHT_DATE        62988   3406  2013/02/16     96       NaN       NaN
# GENDER                   62985      2           男  48134       NaN       NaN
# FFP_TIER                 62988    NaN         NaN    NaN   4.10216  0.373856
# WORK_CITY                60719   3310          广州   9385       NaN       NaN
# WORK_PROVINCE            59740   1185          广东  17507       NaN       NaN
# WORK_COUNTRY             62962    118          CN  57748       NaN       NaN
# AGE                      62568    NaN         NaN    NaN   42.4763   9.88591
# LOAD_TIME                62988      1  2014/03/31  62988       NaN       NaN
# FLIGHT_COUNT             62988    NaN         NaN    NaN   11.8394   14.0495
# ...

# %%
explore = explore[['null', 'max', 'min']]
explore
# Out:
#                          null       max   min
# MEMBER_NO                   0     62988     1
# FFP_DATE                    0       NaN   NaN
# FIRST_FLIGHT_DATE           0       NaN   NaN
# GENDER                      3       NaN   NaN
# FFP_TIER                    0         6     4
# WORK_CITY                2269       NaN   NaN
# WORK_PROVINCE            3248       NaN   NaN
# WORK_COUNTRY               26       NaN   NaN
# AGE                       420       110     6
# LOAD_TIME                   0       NaN   NaN
# FLIGHT_COUNT                0       213     2
# BP_SUM                      0    505308     0
# EP_SUM_YR_1                 0         0     0
# EP_SUM_YR_2                 0     74460     0
# SUM_YR_1                  551    239560     0
# SUM_YR_2                  138    234188     0
# SEG_KM_SUM                  0    580717   368
# WEIGHTED_SEG_KM             0    558440     0
# LAST_FLIGHT_DATE            0       NaN   NaN
# ...

# %%
explore.columns = [u'空值数', u'最大值', u'最小值'] #表头重命名
explore
# Out:
#                           空值数       最大值   最小值
# MEMBER_NO                   0     62988     1
# FFP_DATE                    0       NaN   NaN
# FIRST_FLIGHT_DATE           0       NaN   NaN
# GENDER                      3       NaN   NaN
# FFP_TIER                    0         6     4
# WORK_CITY                2269       NaN   NaN
# WORK_PROVINCE            3248       NaN   NaN
# WORK_COUNTRY               26       NaN   NaN
# AGE                       420       110     6
# LOAD_TIME                   0       NaN   NaN
# FLIGHT_COUNT                0       213     2
# BP_SUM                      0    505308     0
# EP_SUM_YR_1                 0         0     0
# EP_SUM_YR_2                 0     74460     0
# SUM_YR_1                  551    239560     0
# SUM_YR_2                  138    234188     0
# SEG_KM_SUM                  0    580717   368
# WEIGHTED_SEG_KM             0    558440     0
# LAST_FLIGHT_DATE            0       NaN   NaN
# ...

# %%
'''这里只选取部分探索结果。
describe()函数自动计算的字段有count（非空值数）、unique（唯一值数）、top（频数最高者）、freq（最高频数）、mean（平均值）、std（方差）、min（最小值）、50%（中位数）、max（最大值）'''

explore.to_excel(resultfile) #导出结果

# %% [markdown]
# # 2.数据清洗

# %%
#-*- coding: utf-8 -*-
#数据清洗，过滤掉不符合规则的数据

import pandas as pd

datafile= '../data/air_data.csv' #航空原始数据,第一行为属性标签
cleanedfile = '../tmp/data_cleaned.xls' #数据清洗后保存的文件

data = pd.read_csv(datafile,encoding='utf-8') #读取原始数据，指定UTF-8编码（需要用文本编辑器将数据装换为UTF-8编码）

# %%
data[data['SUM_YR_1'].isnull() | data['SUM_YR_2'].isnull()]
# Out:
#        MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER WORK_CITY  \
# 5595       53807  2008/06/20        2008/06/20      男         4        长春
# 6605       43887  2010/08/06        2010/08/15      女         4        上海
# 10196      24497  2012/04/03        2012/04/03      男         4       丽水市
# 16897      34788  2010/11/20        2011/02/22      女         4        上海
# 18177      56998  2007/11/01        2008/01/12      男         4        上海
# ...          ...         ...               ...    ...       ...       ...
# 62923      16431  2013/01/17        2013/01/26      男         4        北京
# 62943       7426  2013/03/22        2013/03/22      男         4        东营
# 62955      50599  2011/10/19        2011/10/19      男         4        上海
# 62979      34330  2013/03/16        2013/03/17      男         4      乌鲁木齐
# 62987      61340  2013/02/17        2013/02/17      女         4        上海
#
#       WORK_PROVINCE WORK_COUNTRY   AGE   LOAD_TIME  ...  ADD_Point_SUM  \
# ...

# %%
data = data[data['SUM_YR_1'].notnull() & data['SUM_YR_2'].notnull()] #票价非空值才保留
data
# Out:
#        MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0          54993  2006/11/02        2008/12/24      男         6            .
# 1          28065  2007/02/19        2007/08/03      男         6          NaN
# 2          55106  2007/02/01        2007/08/30      男         6            .
# 3          21189  2008/08/22        2008/08/23      男         5  Los Angeles
# 4          39546  2009/04/10        2009/04/15      男         6           贵阳
# ...          ...         ...               ...    ...       ...          ...
# 62982      16415  2013/01/20        2013/01/20      女         4           北京
# 62983      18375  2011/05/20        2013/06/05      女         4           广州
# 62984      36041  2010/03/08        2013/09/14      男         4           佛山
# 62985      45690  2006/03/30        2006/12/02      女         4           广州
# 62986      61027  2013/02/06        2013/02/14      女         4           广州
#
# ...

# %%
data.dtypes
# Out:
# MEMBER_NO                    int64
# FFP_DATE                    object
# FIRST_FLIGHT_DATE           object
# GENDER                      object
# FFP_TIER                     int64
# WORK_CITY                   object
# WORK_PROVINCE               object
# WORK_COUNTRY                object
# AGE                        float64
# LOAD_TIME                   object
# FLIGHT_COUNT                 int64
# BP_SUM                       int64
# EP_SUM_YR_1                  int64
# EP_SUM_YR_2                  int64
# SUM_YR_1                     int64
# SUM_YR_2                     int64
# SEG_KM_SUM                   int64
# WEIGHTED_SEG_KM            float64
# LAST_FLIGHT_DATE            object
# AVG_FLIGHT_COUNT           float64
# AVG_BP_SUM                 float64
# BEGIN_TO_FIRST               int64
# LAST_TO_END                  int64
# AVG_INTERVAL               float64
# MAX_INTERVAL                 int64
# ADD_POINTS_SUM_YR_1          int64
# ADD_POINTS_SUM_YR_2          int64
# ...

# %%
#删除票价为0的，或者总飞行公里数为0的记录。
index1 = data['SUM_YR_1'] != 0
index2 = data['SUM_YR_2'] != 0
index3 = (data['SEG_KM_SUM'] == 0)  & (data['avg_discount'] == 0)
data_zero = data[index1 | index2 | index3]
data_zero.T
# Out:
#                               62980       62981       62982       62983  \
# MEMBER_NO                      1761       15206       16415       18375
# FFP_DATE                 2012/08/07  2011/12/02  2013/01/20  2011/05/20
# FIRST_FLIGHT_DATE        2012/09/09  2011/12/02  2013/01/20  2013/06/05
# GENDER                            女           女           女           女
# FFP_TIER                          4           4           4           4
# WORK_CITY                        深圳          广州          北京          广州
# WORK_PROVINCE                    广东          广东           .          广东
# WORK_COUNTRY                     CN          CN          CN          CN
# AGE                            29.0        42.0        35.0        25.0
# LOAD_TIME                2014/03/31  2014/03/31  2014/03/31  2014/03/31
# FLIGHT_COUNT                      2           2           2           2
# BP_SUM                            0           0           0           0
# ...

# %%
data.to_excel(cleanedfile) #导出结果

# %% [markdown]
# # 3.用Feature Selector进行数据清洗

# %%
#-*- coding: utf-8 -*- 
#对数据进行基本的探索
#返回缺失值个数以及最大最小值

import pandas as pd

datafile= '../data/air_data.csv' #航空原始数据,第一行为属性标签
resultfile = '../tmp/explore.xls' #数据探索结果表

data = pd.read_csv(datafile, encoding = 'utf-8') #读取原始数据，指定UTF-8编码（需要用文本编辑器将数据装换为UTF-8编码）

# %%
data.dtypes
# Out:
# MEMBER_NO                    int64
# FFP_DATE                    object
# FIRST_FLIGHT_DATE           object
# GENDER                      object
# FFP_TIER                     int64
# WORK_CITY                   object
# WORK_PROVINCE               object
# WORK_COUNTRY                object
# AGE                        float64
# LOAD_TIME                   object
# FLIGHT_COUNT                 int64
# BP_SUM                       int64
# EP_SUM_YR_1                  int64
# EP_SUM_YR_2                  int64
# SUM_YR_1                   float64
# SUM_YR_2                   float64
# SEG_KM_SUM                   int64
# WEIGHTED_SEG_KM            float64
# LAST_FLIGHT_DATE            object
# AVG_FLIGHT_COUNT           float64
# AVG_BP_SUM                 float64
# BEGIN_TO_FIRST               int64
# LAST_TO_END                  int64
# AVG_INTERVAL               float64
# MAX_INTERVAL                 int64
# ADD_POINTS_SUM_YR_1          int64
# ADD_POINTS_SUM_YR_2          int64
# ...

# %%
import numpy as np
data['FIRST_FLIGHT_DATE']=pd.to_datetime(data['FIRST_FLIGHT_DATE'])
data['LAST_FLIGHT_DATE']=pd.to_datetime(data['LAST_FLIGHT_DATE'])

data['FFP_DATE']=pd.to_datetime(data['FFP_DATE'])
data['LOAD_TIME']=pd.to_datetime(data['LOAD_TIME'])
data['L']=(data['LOAD_TIME']-data['FFP_DATE'])/np.timedelta64(1, 'M')
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ...

# %% [markdown]
# # 3.1、 Missing Values

# %%
missing_info = list(data.columns[data.isnull().any()])
missing_info
# Out:
# ['GENDER',
#  'WORK_CITY',
#  'WORK_PROVINCE',
#  'WORK_COUNTRY',
#  'AGE',
#  'SUM_YR_1',
#  'SUM_YR_2']

# %%
for col in missing_info:
    num_missing_sum = data[data[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, 
                                                    num_missing_sum))
    percent_missing_ratio = data[data[col].isnull() == True].shape[0] / data.shape[0]
    print('percent missing for column {}: {}'.format(
        col, percent_missing_ratio))
# Out:
# number missing for column GENDER: 3
# percent missing for column GENDER: 4.7628119641836543e-05
# number missing for column WORK_CITY: 2269
# percent missing for column WORK_CITY: 0.03602273448910904
# number missing for column WORK_PROVINCE: 3248
# percent missing for column WORK_PROVINCE: 0.05156537753222836
# number missing for column WORK_COUNTRY: 26
# percent missing for column WORK_COUNTRY: 0.0004127770368959167
# number missing for column AGE: 420
# percent missing for column AGE: 0.006667936749857116
# number missing for column SUM_YR_1: 551
# percent missing for column SUM_YR_1: 0.008747697974217311
# number missing for column SUM_YR_2: 138
# percent missing for column SUM_YR_2: 0.002190893503524481

# %%
from feature_selector import FeatureSelector
fs = FeatureSelector(data = data)
# Out:
# No labels provided. Feature importance based methods are not available.

# %%
fs.identify_missing(missing_threshold=0)
# Out:
# 7 features with greater than 0.00 missing values.

# %%
fs.record_missing
# Out:
#          feature  missing_fraction
# 0         GENDER          0.000048
# 1      WORK_CITY          0.036023
# 2  WORK_PROVINCE          0.051565
# 3   WORK_COUNTRY          0.000413
# 4            AGE          0.006668
# 5       SUM_YR_1          0.008748
# 6       SUM_YR_2          0.002191

# %%
fs.missing_stats
# Out:
#                          missing_fraction
# WORK_PROVINCE                    0.051565
# WORK_CITY                        0.036023
# SUM_YR_1                         0.008748
# AGE                              0.006668
# SUM_YR_2                         0.002191
# WORK_COUNTRY                     0.000413
# GENDER                           0.000048
# MEMBER_NO                        0.000000
# Eli_Add_Point_Sum                0.000000
# avg_discount                     0.000000
# P1Y_Flight_Count                 0.000000
# L1Y_Flight_Count                 0.000000
# P1Y_BP_SUM                       0.000000
# L1Y_BP_SUM                       0.000000
# EP_SUM                           0.000000
# ADD_Point_SUM                    0.000000
# Points_Sum                       0.000000
# L1Y_ELi_Add_Points               0.000000
# ADD_POINTS_SUM_YR_2              0.000000
# L1Y_Points_Sum                   0.000000
# Ration_L1Y_Flight_Count          0.000000
# ...

# %% [markdown]
# # 3.2. Single Unique Value

# %%
fs.identify_single_unique()
# Out:
# 2 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
single_unique
# Out:
# ['LOAD_TIME', 'EP_SUM_YR_1']

# %% [markdown]
# # 3.3. Collinear (highly correlated) Features

# %%
fs.identify_collinear(correlation_threshold=0.60)
# Out:
# 23 features with a correlation magnitude greater than 0.60.

# %%
fs.record_collinear
# Out:
#        drop_feature             corr_feature  corr_value
# 0            BP_SUM             FLIGHT_COUNT    0.788379
# 1       EP_SUM_YR_2             FLIGHT_COUNT    0.615746
# 2       EP_SUM_YR_2                   BP_SUM    0.763083
# 3          SUM_YR_1             FLIGHT_COUNT    0.748032
# 4          SUM_YR_1                   BP_SUM    0.850624
# ..              ...                      ...         ...
# 131  Ration_P1Y_BPS  Ration_P1Y_Flight_Count    0.925796
# 132  Ration_L1Y_BPS              LAST_TO_END   -0.607254
# 133  Ration_L1Y_BPS  Ration_L1Y_Flight_Count    0.906347
# 134  Ration_L1Y_BPS  Ration_P1Y_Flight_Count   -0.906347
# 135  Ration_L1Y_BPS           Ration_P1Y_BPS   -0.961415
#
# [136 rows x 3 columns]

# %%
from feature_selector import FeatureSelector
fs = FeatureSelector(data = data)
# Out:
# No labels provided. Feature importance based methods are not available.

# %%
fs.identify_missing(missing_threshold=0)
fs.identify_single_unique()
fs.identify_collinear(correlation_threshold=0.70)
# Out:
# 7 features with greater than 0.00 missing values.
#
# 2 features with a single unique value.
#
# 22 features with a correlation magnitude greater than 0.70.

# %%
fs.plot_collinear()

# %%
data_check_removal=fs.check_removal()
# Out:
# Total of 29 features identified for removal

# %%
fs.ops
# Out:
# {'missing': ['GENDER',
#   'WORK_CITY',
#   'WORK_PROVINCE',
#   'WORK_COUNTRY',
#   'AGE',
#   'SUM_YR_1',
#   'SUM_YR_2'],
#  'single_unique': ['LOAD_TIME', 'EP_SUM_YR_1'],
#  'collinear': ['BP_SUM',
#   'EP_SUM_YR_2',
#   'SUM_YR_1',
#   'SUM_YR_2',
#   'SEG_KM_SUM',
#   'WEIGHTED_SEG_KM',
#   'AVG_FLIGHT_COUNT',
#   'AVG_BP_SUM',
#   'MAX_INTERVAL',
#   'P1Y_Flight_Count',
#   'L1Y_Flight_Count',
#   'P1Y_BP_SUM',
#   'L1Y_BP_SUM',
#   'EP_SUM',
#   'ADD_Point_SUM',
#   'Eli_Add_Point_Sum',
#   'L1Y_ELi_Add_Points',
#   'Points_Sum',
#   'L1Y_Points_Sum',
#   'Ration_P1Y_Flight_Count',
#   'Ration_P1Y_BPS',
#   'Ration_L1Y_BPS']}

# %% [markdown]
# 去除缺失、重复、相关特征后的特征

# %%
set(list(data.columns))-set(fs.ops['missing'])-set(fs.ops['single_unique'])-set(fs.ops['collinear'])
# Out:
# {'ADD_POINTS_SUM_YR_1',
#  'ADD_POINTS_SUM_YR_2',
#  'AVG_INTERVAL',
#  'BEGIN_TO_FIRST',
#  'EXCHANGE_COUNT',
#  'FFP_DATE',
#  'FFP_TIER',
#  'FIRST_FLIGHT_DATE',
#  'FLIGHT_COUNT',
#  'L',
#  'LAST_FLIGHT_DATE',
#  'LAST_TO_END',
#  'MEMBER_NO',
#  'Point_NotFlight',
#  'Ration_L1Y_Flight_Count',
#  'avg_discount'}

# %%
air_quality_removed = fs.remove(methods = ['missing', 'single_unique', 'collinear'], keep_one_hot=False)

# %%
missing_info = list(data.columns[data.isnull().any()])
missing_info
# Out:
# ['GENDER',
#  'WORK_CITY',
#  'WORK_PROVINCE',
#  'WORK_COUNTRY',
#  'AGE',
#  'SUM_YR_1',
#  'SUM_YR_2']
